# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
from keras.models import Sequential
from keras.layers import Input, Concatenate
from keras.layers import Conv2D, Conv2DTranspose, Activation, MaxPooling2D, UpSampling2D
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.models import Model
from keras.models import load_model
from tensorflow.keras.optimizers import Adam
from keras import losses
from google.colab import drive
from google.colab.patches import cv2_imshow

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
rain_images = []
"""
for i in glob.glob("/content/drive/My Drive/AI Project/Dataset/Train/data/*"):
    rain_images.append(cv2.imread(i))
  
for i in glob.glob("/content/drive/My Drive/AI Project/Dataset/Train2/data/*"):
    rain_images.append(cv2.imread(i))
"""
for i in range(861):
    file = "/content/drive/My Drive/AI Project/Dataset/Train/data/" + str(i) + "_rain.png"
    rain_images.append(cv2.imread(file))

for i in range(249):
    file = "/content/drive/My Drive/AI Project/Dataset/Train2/data/" + str(i) + "_rain.jpg"
    rain_images.append(cv2.imread(file))

# %%
derain_images = []
"""
for i in glob.glob("/content/drive/My Drive/AI Project/Dataset/Train/gt/*"):
    derain_images.append(cv2.imread(i))
  
for i in glob.glob("/content/drive/My Drive/AI Project/Dataset/Train2/gt/*"):
    derain_images.append(cv2.imread(i))
"""
for i in range(861):
    file = "/content/drive/My Drive/AI Project/Dataset/Train/gt/" + str(i) + "_clean.png"
    derain_images.append(cv2.imread(file))

for i in range(249):
    file = "/content/drive/My Drive/AI Project/Dataset/Train2/gt/" + str(i) + "_clean.jpg"
    derain_images.append(cv2.imread(file))

# %%
rain_count = 0
derain_count = 0
rain_final = []
derain_final = []
for i in rain_images:
    rain_count +=1
    x = cv2.resize(i,(256,256))
    x = x/255
    rain_final.append(x)

for i in derain_images:
    derain_count +=1
    x = cv2.resize(i,(256,256))
    x = x/255
    derain_final.append(x)

# %%
print(rain_count)
print(derain_count)
# Out:
# 1110
# 1110

# %%
plt.imshow(rain_final[20])

# %%
plt.imshow(derain_final[20])

# %%
plt.imshow(rain_final[100])

# %%
plt.imshow(derain_final[100])

# %%
rain_final = np.asarray(rain_final)
rain_final.shape
# Out:
# (1110, 256, 256, 3)

# %%
derain_final = np.asarray(derain_final)
derain_final.shape
# Out:
# (1110, 256, 256, 3)

# %%
input_img = Input(shape=(256, 256, 3))

x = Conv2D(8, (4, 4), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(16, (4, 4), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(32, (5, 5), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)

encoded = Conv2D(64, (3, 3), activation='relu', padding='same')(x)

# at this point the representation is (32, 32, 64)

x = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (5, 5), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (5, 5), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid',padding = 'same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.summary()
autoencoder.compile(optimizer='adam', loss=losses.mean_squared_error,metrics = ['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 8)       392
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      2064
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        12832
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 32)       18464
#  nspose)
#
#  up_sampling2d (UpSampling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 16)        12816
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 8)       3208
#
#  up_sampling2d_2 (UpSampling  (None, 256, 256, 8)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 3)       219
#
# =================================================================
# Total params: 68,491
# Trainable params: 68,491
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = Model.fit(autoencoder, rain_final, derain_final, validation_split = 0.2, epochs=100, shuffle=True, batch_size=8)
# Out:
# Epoch 1/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0323 - accuracy: 0.3711 - val_loss: 0.0193 - val_accuracy: 0.4148
# Epoch 2/100
# 111/111 [==============================] - 150s 1s/step - loss: 0.0202 - accuracy: 0.3754 - val_loss: 0.0177 - val_accuracy: 0.4059
# Epoch 3/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0184 - accuracy: 0.3762 - val_loss: 0.0159 - val_accuracy: 0.4773
# Epoch 4/100
# 111/111 [==============================] - 156s 1s/step - loss: 0.0175 - accuracy: 0.3866 - val_loss: 0.0206 - val_accuracy: 0.4611
# Epoch 5/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0170 - accuracy: 0.3872 - val_loss: 0.0151 - val_accuracy: 0.4510
# Epoch 6/100
# 111/111 [==============================] - 152s 1s/step - loss: 0.0171 - accuracy: 0.3940 - val_loss: 0.0152 - val_accuracy: 0.4600
# Epoch 7/100
# 111/111 [==============================] - 154s 1s/step - loss: 0.0160 - accuracy: 0.4028 - val_loss: 0.0145 - val_accuracy: 0.4552
# Epoch 8/100
# 111/111 [==============================] - 156s 1s/step - loss: 0.0157 - accuracy: 0.4101 - val_loss: 0.0144 - val_accuracy: 0.4971
# Epoch 9/100
# 111/111 [==============================] - 153s 1s/step - loss: 0.0156 - accuracy: 0.4536 - val_loss: 0.0138 - val_accuracy: 0.5345
# Epoch 10/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0141 - accuracy: 0.5122 - val_loss: 0.0131 - val_accuracy: 0.5323
# Epoch 11/100
# 111/111 [==============================] - 152s 1s/step - loss: 0.0136 - accuracy: 0.5299 - val_loss: 0.0145 - val_accuracy: 0.5411
# Epoch 12/100
# 111/111 [==============================] - 155s 1s/step - loss: 0.0148 - accuracy: 0.4827 - val_loss: 0.0136 - val_accuracy: 0.5057
# Epoch 13/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0135 - accuracy: 0.5299 - val_loss: 0.0128 - val_accuracy: 0.5616
# Epoch 14/100
# 111/111 [==============================] - 163s 1s/step - loss: 0.0128 - accuracy: 0.5679 - val_loss: 0.0127 - val_accuracy: 0.5888
# Epoch 15/100
# 111/111 [==============================] - 164s 1s/step - loss: 0.0130 - accuracy: 0.5683 - val_loss: 0.0135 - val_accuracy: 0.5516
# Epoch 16/100
# 111/111 [==============================] - 173s 2s/step - loss: 0.0130 - accuracy: 0.5744 - val_loss: 0.0132 - val_accuracy: 0.5711
# Epoch 17/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0125 - accuracy: 0.5962 - val_loss: 0.0121 - val_accuracy: 0.5566
# Epoch 18/100
# 111/111 [==============================] - 163s 1s/step - loss: 0.0124 - accuracy: 0.6095 - val_loss: 0.0123 - val_accuracy: 0.6207
# Epoch 19/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0122 - accuracy: 0.6159 - val_loss: 0.0124 - val_accuracy: 0.5831
# Epoch 20/100
# 111/111 [==============================] - 164s 1s/step - loss: 0.0121 - accuracy: 0.6239 - val_loss: 0.0122 - val_accuracy: 0.6028
# Epoch 21/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0124 - accuracy: 0.6042 - val_loss: 0.0127 - val_accuracy: 0.5613
# Epoch 22/100
# 111/111 [==============================] - 168s 2s/step - loss: 0.0122 - accuracy: 0.6068 - val_loss: 0.0125 - val_accuracy: 0.5961
# Epoch 23/100
# 111/111 [==============================] - 167s 2s/step - loss: 0.0119 - accuracy: 0.6315 - val_loss: 0.0120 - val_accuracy: 0.6283
# Epoch 24/100
# 111/111 [==============================] - 164s 1s/step - loss: 0.0117 - accuracy: 0.6393 - val_loss: 0.0119 - val_accuracy: 0.6386
# Epoch 25/100
# 111/111 [==============================] - 172s 2s/step - loss: 0.0118 - accuracy: 0.6266 - val_loss: 0.0121 - val_accuracy: 0.6253
# Epoch 26/100
# 111/111 [==============================] - 164s 1s/step - loss: 0.0117 - accuracy: 0.6442 - val_loss: 0.0116 - val_accuracy: 0.5951
# Epoch 27/100
# 111/111 [==============================] - 167s 2s/step - loss: 0.0116 - accuracy: 0.6364 - val_loss: 0.0122 - val_accuracy: 0.5858
# Epoch 28/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0117 - accuracy: 0.6228 - val_loss: 0.0119 - val_accuracy: 0.6065
# Epoch 29/100
# 111/111 [==============================] - 165s 1s/step - loss: 0.0117 - accuracy: 0.6452 - val_loss: 0.0128 - val_accuracy: 0.5387
# Epoch 30/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0116 - accuracy: 0.6145 - val_loss: 0.0120 - val_accuracy: 0.4809
# Epoch 31/100
# 111/111 [==============================] - 166s 1s/step - loss: 0.0115 - accuracy: 0.6258 - val_loss: 0.0126 - val_accuracy: 0.5538
# Epoch 32/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0118 - accuracy: 0.6140 - val_loss: 0.0113 - val_accuracy: 0.6173
# Epoch 33/100
# 111/111 [==============================] - 163s 1s/step - loss: 0.0113 - accuracy: 0.6469 - val_loss: 0.0113 - val_accuracy: 0.6197
# Epoch 34/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0116 - accuracy: 0.6227 - val_loss: 0.0112 - val_accuracy: 0.6451
# Epoch 35/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0112 - accuracy: 0.6557 - val_loss: 0.0112 - val_accuracy: 0.6409
# Epoch 36/100
# 111/111 [==============================] - 157s 1s/step - loss: 0.0113 - accuracy: 0.6419 - val_loss: 0.0113 - val_accuracy: 0.5655
# Epoch 37/100
# 111/111 [==============================] - 153s 1s/step - loss: 0.0111 - accuracy: 0.6337 - val_loss: 0.0114 - val_accuracy: 0.6266
# Epoch 38/100
# 111/111 [==============================] - 157s 1s/step - loss: 0.0112 - accuracy: 0.6464 - val_loss: 0.0120 - val_accuracy: 0.5534
# Epoch 39/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0110 - accuracy: 0.6345 - val_loss: 0.0115 - val_accuracy: 0.6202
# Epoch 40/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0111 - accuracy: 0.6518 - val_loss: 0.0116 - val_accuracy: 0.6288
# Epoch 41/100
# 111/111 [==============================] - 150s 1s/step - loss: 0.0114 - accuracy: 0.6265 - val_loss: 0.0114 - val_accuracy: 0.6319
# Epoch 42/100
# 111/111 [==============================] - 149s 1s/step - loss: 0.0110 - accuracy: 0.6453 - val_loss: 0.0110 - val_accuracy: 0.5941
# Epoch 43/100
# 111/111 [==============================] - 153s 1s/step - loss: 0.0112 - accuracy: 0.6350 - val_loss: 0.0151 - val_accuracy: 0.4701
# Epoch 44/100
# 111/111 [==============================] - 150s 1s/step - loss: 0.0110 - accuracy: 0.6437 - val_loss: 0.0110 - val_accuracy: 0.6433
# Epoch 45/100
# 111/111 [==============================] - 151s 1s/step - loss: 0.0112 - accuracy: 0.6357 - val_loss: 0.0114 - val_accuracy: 0.5252
# Epoch 46/100
# 111/111 [==============================] - 149s 1s/step - loss: 0.0110 - accuracy: 0.6452 - val_loss: 0.0109 - val_accuracy: 0.6435
# Epoch 47/100
# 111/111 [==============================] - 149s 1s/step - loss: 0.0107 - accuracy: 0.6551 - val_loss: 0.0112 - val_accuracy: 0.6494
# Epoch 48/100
# 111/111 [==============================] - 149s 1s/step - loss: 0.0108 - accuracy: 0.6448 - val_loss: 0.0111 - val_accuracy: 0.6036
# Epoch 49/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0109 - accuracy: 0.6522 - val_loss: 0.0118 - val_accuracy: 0.5775
# Epoch 50/100
# 111/111 [==============================] - 149s 1s/step - loss: 0.0106 - accuracy: 0.6634 - val_loss: 0.0109 - val_accuracy: 0.6016
# Epoch 51/100
# 111/111 [==============================] - 154s 1s/step - loss: 0.0105 - accuracy: 0.6658 - val_loss: 0.0113 - val_accuracy: 0.6077
# Epoch 52/100
# 111/111 [==============================] - 155s 1s/step - loss: 0.0107 - accuracy: 0.6594 - val_loss: 0.0111 - val_accuracy: 0.6341
# Epoch 53/100
# 111/111 [==============================] - 156s 1s/step - loss: 0.0105 - accuracy: 0.6639 - val_loss: 0.0111 - val_accuracy: 0.6430
# Epoch 54/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0105 - accuracy: 0.6610 - val_loss: 0.0108 - val_accuracy: 0.6277
# Epoch 55/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0106 - accuracy: 0.6590 - val_loss: 0.0114 - val_accuracy: 0.6414
# Epoch 56/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0106 - accuracy: 0.6501 - val_loss: 0.0110 - val_accuracy: 0.6196
# Epoch 57/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0106 - accuracy: 0.6562 - val_loss: 0.0113 - val_accuracy: 0.6232
# Epoch 58/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0106 - accuracy: 0.6470 - val_loss: 0.0108 - val_accuracy: 0.6459
# Epoch 59/100
# 111/111 [==============================] - 164s 1s/step - loss: 0.0106 - accuracy: 0.6553 - val_loss: 0.0110 - val_accuracy: 0.6415
# Epoch 60/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0105 - accuracy: 0.6515 - val_loss: 0.0107 - val_accuracy: 0.6257
# Epoch 61/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0106 - accuracy: 0.6521 - val_loss: 0.0112 - val_accuracy: 0.6389
# Epoch 62/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0102 - accuracy: 0.6653 - val_loss: 0.0108 - val_accuracy: 0.6385
# Epoch 63/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0104 - accuracy: 0.6632 - val_loss: 0.0107 - val_accuracy: 0.6190
# Epoch 64/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0101 - accuracy: 0.6737 - val_loss: 0.0123 - val_accuracy: 0.5963
# Epoch 65/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0103 - accuracy: 0.6582 - val_loss: 0.0106 - val_accuracy: 0.6373
# Epoch 66/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0104 - accuracy: 0.6616 - val_loss: 0.0105 - val_accuracy: 0.6109
# Epoch 67/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0102 - accuracy: 0.6633 - val_loss: 0.0107 - val_accuracy: 0.6617
# Epoch 68/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0102 - accuracy: 0.6562 - val_loss: 0.0104 - val_accuracy: 0.6564
# Epoch 69/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0101 - accuracy: 0.6699 - val_loss: 0.0105 - val_accuracy: 0.6325
# Epoch 70/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0101 - accuracy: 0.6629 - val_loss: 0.0107 - val_accuracy: 0.6514
# Epoch 71/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0100 - accuracy: 0.6683 - val_loss: 0.0117 - val_accuracy: 0.6657
# Epoch 72/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0101 - accuracy: 0.6707 - val_loss: 0.0105 - val_accuracy: 0.6445
# Epoch 73/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0101 - accuracy: 0.6663 - val_loss: 0.0104 - val_accuracy: 0.6480
# Epoch 74/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0105 - accuracy: 0.6392 - val_loss: 0.0114 - val_accuracy: 0.6493
# Epoch 75/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0102 - accuracy: 0.6625 - val_loss: 0.0105 - val_accuracy: 0.6215
# Epoch 76/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0100 - accuracy: 0.6687 - val_loss: 0.0106 - val_accuracy: 0.6292
# Epoch 77/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0101 - accuracy: 0.6586 - val_loss: 0.0115 - val_accuracy: 0.6346
# Epoch 78/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0100 - accuracy: 0.6749 - val_loss: 0.0108 - val_accuracy: 0.6511
# Epoch 79/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0102 - accuracy: 0.6487 - val_loss: 0.0104 - val_accuracy: 0.6425
# Epoch 80/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0100 - accuracy: 0.6738 - val_loss: 0.0105 - val_accuracy: 0.6548
# Epoch 81/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0098 - accuracy: 0.6676 - val_loss: 0.0102 - val_accuracy: 0.6421
# Epoch 82/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0100 - accuracy: 0.6728 - val_loss: 0.0108 - val_accuracy: 0.5699
# Epoch 83/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0102 - accuracy: 0.6412 - val_loss: 0.0110 - val_accuracy: 0.5057
# Epoch 84/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0099 - accuracy: 0.6579 - val_loss: 0.0108 - val_accuracy: 0.6403
# Epoch 85/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0100 - accuracy: 0.6571 - val_loss: 0.0106 - val_accuracy: 0.6461
# Epoch 86/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0099 - accuracy: 0.6655 - val_loss: 0.0106 - val_accuracy: 0.6496
# Epoch 87/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0097 - accuracy: 0.6691 - val_loss: 0.0113 - val_accuracy: 0.6109
# Epoch 88/100
# 111/111 [==============================] - 162s 1s/step - loss: 0.0098 - accuracy: 0.6603 - val_loss: 0.0103 - val_accuracy: 0.6400
# Epoch 89/100
# 111/111 [==============================] - 163s 1s/step - loss: 0.0098 - accuracy: 0.6749 - val_loss: 0.0103 - val_accuracy: 0.6224
# Epoch 90/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0097 - accuracy: 0.6696 - val_loss: 0.0104 - val_accuracy: 0.6466
# Epoch 91/100
# 111/111 [==============================] - 163s 1s/step - loss: 0.0098 - accuracy: 0.6717 - val_loss: 0.0103 - val_accuracy: 0.6011
# Epoch 92/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0102 - accuracy: 0.6188 - val_loss: 0.0115 - val_accuracy: 0.5823
# Epoch 93/100
# 111/111 [==============================] - 161s 1s/step - loss: 0.0099 - accuracy: 0.6592 - val_loss: 0.0110 - val_accuracy: 0.5812
# Epoch 94/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0099 - accuracy: 0.6537 - val_loss: 0.0104 - val_accuracy: 0.6103
# Epoch 95/100
# 111/111 [==============================] - 160s 1s/step - loss: 0.0097 - accuracy: 0.6746 - val_loss: 0.0102 - val_accuracy: 0.6472
# Epoch 96/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0097 - accuracy: 0.6671 - val_loss: 0.0103 - val_accuracy: 0.6214
# Epoch 97/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0097 - accuracy: 0.6639 - val_loss: 0.0103 - val_accuracy: 0.6564
# Epoch 98/100
# 111/111 [==============================] - 158s 1s/step - loss: 0.0099 - accuracy: 0.6465 - val_loss: 0.0108 - val_accuracy: 0.6315
# Epoch 99/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0097 - accuracy: 0.6571 - val_loss: 0.0102 - val_accuracy: 0.6578
# Epoch 100/100
# 111/111 [==============================] - 159s 1s/step - loss: 0.0096 - accuracy: 0.6707 - val_loss: 0.0103 - val_accuracy: 0.6272

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
autoencoder.save("./AI_Denoising_WeightsAfter100Epochs3layers256size")
# !zip -r /content/AI_Denoising_WeightsAfter100Epochs3layers256size.zip /content/AI_Denoising_WeightsAfter100Epochs3layers256size/
# Out:
# INFO:tensorflow:Assets written to: ./AI_Denoising_WeightsAfter100Epochs3layers256size/assets
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/ (stored 0%)
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/assets/ (stored 0%)
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/keras_metadata.pb (deflated 93%)
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/saved_model.pb (deflated 91%)
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/variables/ (stored 0%)
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/variables/variables.data-00000-of-00001 (deflated 10%)
#   adding: content/AI_Denoising_WeightsAfter100Epochs3layers256size/variables/variables.index (deflated 71%)

# %%
test_rain_images = []
for i in range(58):
    file = "/content/drive/My Drive/AI Project/Dataset/Test/data/" + str(i) + "_rain.png"
    test_rain_images.append(cv2.imread(file))

# %%
test_clean_images = []
for i in range(58):
    file = "/content/drive/My Drive/AI Project/Dataset/Test/gt/" + str(i) + "_clean.png"
    test_clean_images.append(cv2.imread(file))

# %%
plt.imshow(test_rain_images[2])

# %%
test_rain_final_images = []
for i in test_rain_images:
    x = cv2.resize(i,(256,256))
    x = x/255
    test_rain_final_images.append(x)

test_clean_final_images = []
for i in test_clean_images:
    x = cv2.resize(i,(256,256))
    x = x/255
    test_clean_final_images.append(x)

# %%
test_rain_final_images = np.asarray(test_rain_final_images)
test_rain_final_images.shape 
test_derained_final_images = autoencoder.predict(test_rain_final_images)

# %%
plt.imshow(test_derained_final_images[21])

# %%
plt.imshow(test_rain_final_images[21])

# %%
mse = ((test_clean_final_images - test_derained_final_images) ** 2).mean(axis=None)
mse
# Out:
# 0.005899833672059695

# %%
psnr = 20*np.log10(1/(mse**(1/2.0)))
psnr
# Out:
# 22.291602318027508
